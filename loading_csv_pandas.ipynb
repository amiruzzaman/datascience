# %% [markdown]
# ## How to read a csv file using pandas

# %%
import pandas as pd
# Read the csv file
df = pd.read_csv("onlineBanking.csv")

# %% [markdown]
# ## First 5 rows

# %%
# First 5 rows
df.head()
# Out:
#    min_fpktl  mean_fpktl  max_fpktl  std_fpktl  min_bpktl  mean_bpktl  \
# 0         40          78        862        164         40        1257
# 1         40         296        866        376         40         189
# 2         40         297        860        377         40         311
# 3         40          89        862        189         40        1259
# 4         40         299        866        375         40         446
#
#    max_bpktl  std_bpktl  min_fiat  mean_fiat  ...  mean_biat  max_biat  \
# 0       1420        410        55      12781  ...      11650    246300
# 1        450        161       735      51795  ...      62576    151962
# 2       1063        376      1294      51746  ...      62559    155276
# 3       1420        404        55      16884  ...      14060    420000
# 4       1420        530        25      50451  ...      60922    151962
#
#    std_biat  duration  proto  total_fpackets  total_fvolume  total_bpackets  \
# ...

# %% [markdown]
# ## The whole dataset

# %%
# Dataframe
df
# Out:
#     min_fpktl  mean_fpktl  max_fpktl  std_fpktl  min_bpktl  mean_bpktl  \
# 0          40          78        862        164         40        1257
# 1          40         296        866        376         40         189
# 2          40         297        860        377         40         311
# 3          40          89        862        189         40        1259
# 4          40         299        866        375         40         446
# 5          40         337        860        389         40         330
# 6          40          89        862        189         40        1259
# 7          40         299        866        375         40         446
# 8          40         337        860        389         40         330
# 9          40          99        862        206         40        1262
# 10         40         185        866        306         40        1036
# 11         40         331        860        386         40         403
# ...

# %% [markdown]
# ## Get the column names

# %%
df.columns
# Out:
# Index(['min_fpktl', 'mean_fpktl', 'max_fpktl', 'std_fpktl', 'min_bpktl',
#        'mean_bpktl', 'max_bpktl', 'std_bpktl', 'min_fiat', 'mean_fiat',
#        'max_fiat', 'std_fiat', 'min_biat', 'mean_biat', 'max_biat', 'std_biat',
#        'duration', 'proto', 'total_fpackets', 'total_fvolume',
#        'total_bpackets', 'total_bvolume', 'class'],
#       dtype='object')

# %% [markdown]
# ## Get a specific column

# %%
df['class']
# Out:
# 0     ONLINEBANKING
# 1     ONLINEBANKING
# 2     ONLINEBANKING
# 3     ONLINEBANKING
# 4     ONLINEBANKING
# 5     ONLINEBANKING
# 6     ONLINEBANKING
# 7     ONLINEBANKING
# 8     ONLINEBANKING
# 9     ONLINEBANKING
# 10    ONLINEBANKING
# 11    ONLINEBANKING
# 12    ONLINEBANKING
# 13    ONLINEBANKING
# 14    ONLINEBANKING
# 15    ONLINEBANKING
# 16    ONLINEBANKING
# 17    ONLINEBANKING
# 18    ONLINEBANKING
# 19    ONLINEBANKING
# 20    ONLINEBANKING
# 21    ONLINEBANKING
# Name: class, dtype: object

# %% [markdown]
# ## Get more than one columns

# %%
df[['min_fpktl', 'class', 'max_biat']]
# Out:
#     min_fpktl          class  max_biat
# 0          40  ONLINEBANKING    246300
# 1          40  ONLINEBANKING    151962
# 2          40  ONLINEBANKING    155276
# 3          40  ONLINEBANKING    420000
# 4          40  ONLINEBANKING    151962
# 5          40  ONLINEBANKING    223513
# 6          40  ONLINEBANKING    420000
# 7          40  ONLINEBANKING    151962
# 8          40  ONLINEBANKING    223513
# 9          40  ONLINEBANKING    420000
# 10         40  ONLINEBANKING    151962
# 11         40  ONLINEBANKING    223513
# 12         40  ONLINEBANKING    358280
# 13         40  ONLINEBANKING    122378
# 14         40  ONLINEBANKING     54598
# 15         40  ONLINEBANKING    697657
# 16         40  ONLINEBANKING    324224
# 17         40  ONLINEBANKING    358280
# 18         40  ONLINEBANKING    122378
# 19         40  ONLINEBANKING     54598
# 20         40  ONLINEBANKING    697657
# 21         40  ONLINEBANKING    324224

# %% [markdown]
# ## Pass the coulmn names as array

# %%
arr = ['min_fpktl', 'class', 'max_biat']
df[arr]
# Out:
#     min_fpktl          class  max_biat
# 0          40  ONLINEBANKING    246300
# 1          40  ONLINEBANKING    151962
# 2          40  ONLINEBANKING    155276
# 3          40  ONLINEBANKING    420000
# 4          40  ONLINEBANKING    151962
# 5          40  ONLINEBANKING    223513
# 6          40  ONLINEBANKING    420000
# 7          40  ONLINEBANKING    151962
# 8          40  ONLINEBANKING    223513
# 9          40  ONLINEBANKING    420000
# 10         40  ONLINEBANKING    151962
# 11         40  ONLINEBANKING    223513
# 12         40  ONLINEBANKING    358280
# 13         40  ONLINEBANKING    122378
# 14         40  ONLINEBANKING     54598
# 15         40  ONLINEBANKING    697657
# 16         40  ONLINEBANKING    324224
# 17         40  ONLINEBANKING    358280
# 18         40  ONLINEBANKING    122378
# 19         40  ONLINEBANKING     54598
# 20         40  ONLINEBANKING    697657
# 21         40  ONLINEBANKING    324224

# %% [markdown]
# ## Get first two rows

# %%
df.head(2)
# Out:
#    min_fpktl  mean_fpktl  max_fpktl  std_fpktl  min_bpktl  mean_bpktl  \
# 0         40          78        862        164         40        1257
# 1         40         296        866        376         40         189
#
#    max_bpktl  std_bpktl  min_fiat  mean_fiat  ...  mean_biat  max_biat  \
# 0       1420        410        55      12781  ...      11650    246300
# 1        450        161       735      51795  ...      62576    151962
#
#    std_biat  duration  proto  total_fpackets  total_fvolume  total_bpackets  \
# 0     39262    575174      6              46           3599              46
# 1     56271    466156      6              10           2968               7
#
#    total_bvolume          class
# 0          57839  ONLINEBANKING
# 1           1329  ONLINEBANKING
#
# [2 rows x 23 columns]

# %% [markdown]
# ## Get descriptive statistics

# %%
# https://www.datasciencemadesimple.com/descriptive-summary-statistics-python-pandas/
df.describe()
# Out:
#        min_fpktl  mean_fpktl    max_fpktl   std_fpktl  min_bpktl   mean_bpktl  \
# count       22.0   22.000000    22.000000   22.000000       22.0    22.000000
# mean        40.0  203.772727   908.272727  300.636364       40.0   876.636364
# std          0.0   99.655565    97.294928   88.516098        0.0   402.564582
# min         40.0   78.000000   860.000000  164.000000       40.0   189.000000
# 25%         40.0  102.000000   862.000000  213.000000       40.0   446.000000
# 50%         40.0  196.500000   865.000000  331.000000       40.0  1023.500000
# 75%         40.0  298.500000   869.000000  376.750000       40.0  1248.000000
# max         40.0  337.000000  1138.000000  409.000000       40.0  1297.000000
#
#          max_bpktl   std_bpktl     min_fiat      mean_fiat  ...     min_biat  \
# count    22.000000   22.000000    22.000000      22.000000  ...    22.000000
# mean   1327.227273  453.681818   273.500000   42127.090909  ...   210.818182
# ...

# %% [markdown]
# ## Get object

# %%
df.describe(include=['object'])
# Out:
#                 class
# count              22
# unique              1
# top     ONLINEBANKING
# freq               22

# %% [markdown]
# ## Get all statistics

# %%
df.describe(include='all')
# Out:
#         min_fpktl  mean_fpktl    max_fpktl   std_fpktl  min_bpktl  \
# count        22.0   22.000000    22.000000   22.000000       22.0
# unique        NaN         NaN          NaN         NaN        NaN
# top           NaN         NaN          NaN         NaN        NaN
# freq          NaN         NaN          NaN         NaN        NaN
# mean         40.0  203.772727   908.272727  300.636364       40.0
# std           0.0   99.655565    97.294928   88.516098        0.0
# min          40.0   78.000000   860.000000  164.000000       40.0
# 25%          40.0  102.000000   862.000000  213.000000       40.0
# 50%          40.0  196.500000   865.000000  331.000000       40.0
# 75%          40.0  298.500000   869.000000  376.750000       40.0
# max          40.0  337.000000  1138.000000  409.000000       40.0
#
#          mean_bpktl    max_bpktl   std_bpktl     min_fiat      mean_fiat  ...  \
# count     22.000000    22.000000   22.000000    22.000000      22.000000  ...
# ...

# %% [markdown]
# ## Get column names

# %%
df.columns
# Out:
# Index(['min_fpktl', 'mean_fpktl', 'max_fpktl', 'std_fpktl', 'min_bpktl',
#        'mean_bpktl', 'max_bpktl', 'std_bpktl', 'min_fiat', 'mean_fiat',
#        'max_fiat', 'std_fiat', 'min_biat', 'mean_biat', 'max_biat', 'std_biat',
#        'duration', 'proto', 'total_fpackets', 'total_fvolume',
#        'total_bpackets', 'total_bvolume', 'class'],
#       dtype='object')

# %% [markdown]
# ## Get the column 'duration'

# %%
df['duration']
# Out:
# 0       575174
# 1       466156
# 2       465721
# 3     11446594
# 4     11159117
# 5     11231565
# 6     11446594
# 7     11159117
# 8     11231565
# 9     30630419
# 10    30456211
# 11    30622583
# 12     2917579
# 13     3019723
# 14     2981791
# 15     1553398
# 16     3075204
# 17    11491572
# 18    11608454
# 19     2981791
# 20    11368177
# 21     3075204
# Name: duration, dtype: int64

# %% [markdown]
# ## Get 10 rows of column 'duration'

# %%
df['duration'][0:10]
# Out:
# 0      575174
# 1      466156
# 2      465721
# 3    11446594
# 4    11159117
# 5    11231565
# 6    11446594
# 7    11159117
# 8    11231565
# 9    30630419
# Name: duration, dtype: int64

# %% [markdown]
# ## Get two columns at the same time

# %%
df[['duration','total_bvolume']]
# Out:
#     duration  total_bvolume
# 0     575174          57839
# 1     466156           1329
# 2     465721           2178
# 3   11446594          88152
# 4   11159117           4466
# 5   11231565           2975
# 6   11446594          88152
# 7   11159117           4466
# 8   11231565           2975
# 9   30630419          90882
# 10  30456211          27987
# 11  30622583           4435
# 12   2917579          46964
# 13   3019723          10901
# 14   2981791          75230
# 15   1553398           8891
# 16   3075204          59830
# 17  11491572          70485
# 18  11608454          19227
# 19   2981791          75230
# 20  11368177          18449
# 21   3075204          59830

# %% [markdown]
# ## Create a new column

# %%
df['new_column'] = df['duration'] +df['total_bvolume']

# %% [markdown]
# ## Get the newly created column

# %%
df['new_column']
# Out:
# 0       633013
# 1       467485
# 2       467899
# 3     11534746
# 4     11163583
# 5     11234540
# 6     11534746
# 7     11163583
# 8     11234540
# 9     30721301
# 10    30484198
# 11    30627018
# 12     2964543
# 13     3030624
# 14     3057021
# 15     1562289
# 16     3135034
# 17    11562057
# 18    11627681
# 19     3057021
# 20    11386626
# 21     3135034
# Name: new_column, dtype: int64

# %% [markdown]
# ## Get head

# %%
df.head
# Out:
# <bound method NDFrame.head of     min_fpktl  mean_fpktl  max_fpktl  std_fpktl  min_bpktl  mean_bpktl  \
# 0          40          78        862        164         40        1257
# 1          40         296        866        376         40         189
# 2          40         297        860        377         40         311
# 3          40          89        862        189         40        1259
# 4          40         299        866        375         40         446
# 5          40         337        860        389         40         330
# 6          40          89        862        189         40        1259
# 7          40         299        866        375         40         446
# 8          40         337        860        389         40         330
# 9          40          99        862        206         40        1262
# 10         40         185        866        306         40        1036
# 11         40         331        860        386         40         403
# ...

# %% [markdown]
# ## Get the whole dataframe

# %%
df
# Out:
#     min_fpktl  mean_fpktl  max_fpktl  std_fpktl  min_bpktl  mean_bpktl  \
# 0          40          78        862        164         40        1257
# 1          40         296        866        376         40         189
# 2          40         297        860        377         40         311
# 3          40          89        862        189         40        1259
# 4          40         299        866        375         40         446
# 5          40         337        860        389         40         330
# 6          40          89        862        189         40        1259
# 7          40         299        866        375         40         446
# 8          40         337        860        389         40         330
# 9          40          99        862        206         40        1262
# 10         40         185        866        306         40        1036
# 11         40         331        860        386         40         403
# ...

# %% [markdown]
# ## Save everything including the new column to a new csv file

# %%
df.to_csv("newcsvfile.csv")

# %% [markdown]
# ## Plot using pandas

# %%
df_new_column = df['new_column'].cumsum()

df_new_column.plot();

# %% [markdown]
# ## Bar graph

# %%
df_new_column.plot(kind="bar");

# %% [markdown]
# ## multi column bar chart

# %%
import numpy as np
df2 = pd.DataFrame(np.random.rand(10, 3), columns=['mean_bpktl','max_bpktl','std_bpktl'])

df2.plot.bar();

# %% [markdown]
# ## Histogram

# %%
columns=['mean_bpktl','max_bpktl','std_bpktl']
df4 = df[columns]
df4.plot.hist(alpha=0.5);

# %% [markdown]
# ## Scatterplot

# %%
df.plot.scatter(x="mean_bpktl", y="max_bpktl");
