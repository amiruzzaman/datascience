# %%
import pandas as pd
# Read the csv file
df = pd.read_csv("baddata.csv")
# Out:
# C:\Users\mamiruzz\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#          city state  price  amount quality      date    ppg      state.name  \
# 0   Annandale    VA  100.0   7.075    high  9/2/2010  14.13        Virginia
# 1      Auburn    AL   60.0  28.300    high  9/2/2010   2.12         Alabama
# 2      Austin    TX   60.0  28.300  medium  9/2/2010   2.12           Texas
# 3  Belleville    IL  400.0  28.300    high  9/2/2010  14.13        Illinois
# 4       Boone    NC   55.0   3.540    high  9/2/2010  15.54  North Carolina
#
#          lat        lon
# 0  38.830345 -77.213870
# 1  32.578185 -85.472820
# 2  30.326374 -97.771258
# 3  38.532311 -89.983521
# 4  36.217052 -81.687983

# %% [markdown]
# # number of rows

# %%
df[df.columns[0]].count()
# Out:
# 147083

# %% [markdown]
# # select n number of rows randomly

# %%
df_new = df.sample(n = 30)
df_new
# Out:
#                   city state  price  amount quality        date    ppg  \
# 19744   Salt Lake City    UT  160.0  14.150    high   7/28/2011  11.31
# 35075          Chicago    IL  350.0  28.300    high   4/30/2012  12.37
# 25057          Manteca    CA  300.0  28.300    high  11/15/2011   10.6
# 63363      Yorba Linda    CA   15.0   5.000    high   11/2/2012      3
# 94848      New Orleans    LA  320.0  28.300    high   3/28/2013  11.31
# 60724        Beaverton    OR  200.0  28.300  medium  10/20/2012   7.07
# 84059      New Orleans    LA   45.0   3.540  medium    2/4/2013  12.71
# 23445          Modesto    CA   20.0   5.000  medium   10/4/2011      4
# 146545         Warwick    RI   40.0   3.540    high    5/7/2014   11.3
# 108200          Albany    NY   60.0   3.540  medium    6/7/2013  16.95
# 43615    Fort Stockton    TX  100.0   5.000    high    7/7/2012     20
# 777          Iowa City    IA   60.0   3.540  medium   9/14/2010  16.95
# ...

# %%
df_new[df_new.columns[0]].count()
# Out:
# 30

# %% [markdown]
# # save it to a new file

# %%
file_name = 'baddata_n30.csv'
df_new.to_csv(file_name, sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ## Print column names

# %%
df.columns
# Out:
# Index(['city', 'state', 'price', 'amount', 'quality', 'date', 'ppg',
#        'state.name', 'lat', 'lon'],
#       dtype='object')

# %% [markdown]
# ## Find duplicate based on more than one column

# %%
df[df[['city', 'state', 'price', 'amount', 'quality', 'date', 'ppg',
       'state.name', 'lat', 'lon']].duplicated() == True]
# Out:
#                    city state  price  amount quality       date    ppg  \
# 146754       Zionsville    IN  100.0    3.54    high  5/10/2014  28.25
# 146755       Zionsville    IN  100.0    3.54    high  5/10/2014  28.25
# 146756       Zionsville    IN  100.0    3.54    high  5/10/2014  28.25
# 146759            Akron    OH  300.0   28.30  medium  5/11/2014   10.6
# 146760            Akron    OH  300.0   28.30  medium  5/11/2014   10.6
# 146761            Akron    OH  300.0   28.30  medium  5/11/2014   10.6
# 146892  North Las Vegas    NV  150.0   14.15  medium  5/12/2014   10.6
# 146893  North Las Vegas    NV  150.0   14.15  medium  5/12/2014   10.6
# 146894  North Las Vegas    NV  150.0   14.15  medium  5/12/2014   10.6
# 146895  North Las Vegas    NV  150.0   14.15  medium  5/12/2014   10.6
#
#        state.name        lat         lon
# 146754    Indiana  39.960858  -86.282520
# 146755    Indiana  39.960858  -86.282520
# 146756    Indiana  39.960858  -86.282520
# ...

# %%
df
# Out:
#                     city state  price  amount quality       date    ppg  \
# 0              Annandale    VA  100.0   7.075    high   9/2/2010  14.13
# 1                 Auburn    AL   60.0  28.300    high   9/2/2010   2.12
# 2                 Austin    TX   60.0  28.300  medium   9/2/2010   2.12
# 3             Belleville    IL  400.0  28.300    high   9/2/2010  14.13
# 4                  Boone    NC   55.0   3.540    high   9/2/2010  15.54
# 5                Boulder    CO  300.0  28.300    high   9/2/2010   10.6
# 6               Brighton    MA  300.0  28.300    high   9/2/2010   10.6
# 7               Brooklyn    NY   20.0   3.540    high   9/2/2010   5.65
# 8               Brooklyn    NY   80.0   3.540    high   9/2/2010   22.6
# 9               Brooklyn    NY   60.0   3.540  medium   9/2/2010  16.95
# 10            Burlington    VT  450.0  28.300    high   9/2/2010   15.9
# 11               Chicago    IL  520.0  28.300    high   9/2/2010  18.37
# ...

# %% [markdown]
# ## checking a specific column

# %%
# creating bool series True for NaN values 
missing_state = pd.isnull(df["state"]) 
    
# filtering data 
# displaying data only with Gender = NaN 
df[missing_state]
# Out:
#         city state  price  amount quality      date ppg  state.name  \
# 120954  Yelm   NaN    NaN     NaN  medium  8/6/2013  10  Washington
#
#               lat        lon
# 120954  46.893352 -122.56719

# %%
# creating bool series True for NaN values 
missing_price = pd.isnull(df["price"]) 
    
# filtering data 
# displaying data only with Gender = NaN 
df[missing_price]
# Out:
#         city state  price  amount quality      date ppg  state.name  \
# 120954  Yelm   NaN    NaN     NaN  medium  8/6/2013  10  Washington
#
#               lat        lon
# 120954  46.893352 -122.56719

# %% [markdown]
# ## Find similar rows

# %%
df[df.city.isin(['Yelm'])]
# Out:
#         city state  price  amount quality       date         ppg  state.name  \
# 8431    Yelm    WA  250.0   28.30    high  11/3/2010        8.83  Washington
# 19041   Yelm    WA  150.0   28.30    high  7/14/2011         5.3  Washington
# 20210   Yelm    WA  230.0   28.30    high   8/5/2011        8.13  Washington
# 25985   Yelm    WA   50.0    5.00  medium  12/6/2011          10  Washington
# 51395   Yelm    WA   20.0    5.00  medium  8/19/2012           4  Washington
# 101622  Yelm    WA   17.0    5.00    high   5/2/2013         3.4  Washington
# 102431  Yelm    WA  175.0   28.30    high   5/7/2013        6.18  Washington
# 118567  Yelm    WA   44.0    5.00    high  7/26/2013         8.8  Washington
# 120952  Yelm    WA   50.0    5.00  medium   8/6/2013          10  Washington
# 120953  Yelm    WA   50.0    5.00  medium        NaN  Washington   46.893352
# 120954  Yelm   NaN    NaN     NaN  medium   8/6/2013          10  Washington
# ...

# %% [markdown]
# ## Missing values for a specific column

# %%
df[df['state'].isna()]
# Out:
#         city state  price  amount quality      date ppg  state.name  \
# 120954  Yelm   NaN    NaN     NaN  medium  8/6/2013  10  Washington
#
#               lat        lon
# 120954  46.893352 -122.56719

# %% [markdown]
# ## Missing values in entire df

# %%
df[df.isna().any(axis=1)]
# Out:
#                    city state  price  amount quality        date         ppg  \
# 1356        Walla Walla    WA   25.0  20.000    high   9/14/2010        1.25
# 1357        Walla Walla    WA  100.0  28.300     low   9/14/2010        3.53
# 1358        Walla Walla    WA   50.0   3.540    high   9/14/2010       14.12
# 3542      West Hartford    CT  380.0  28.300    high   9/20/2010       13.43
# 5776      West Hartford    CT   45.0   3.540  medium   9/29/2010       12.71
# 6775      West Hartford    CT  100.0   5.000    high   10/6/2010          20
# 6903       Toccoa Falls    GA   65.0  14.150  medium   10/7/2010        4.59
# 8221            Shawnee    KS   80.0   7.075    high   11/1/2010       11.31
# 8222            Shawnee    KS   80.0  28.300  medium   11/1/2010        2.83
# 8972            Shawnee    KS   55.0   3.540    high  11/15/2010       15.54
# 10572     West Hartford    CT   50.0  28.300  medium  12/21/2010        1.77
# ...

# %% [markdown]
# ## remove any rows without a city

# %%
# df1 = df.dropna(subset=['city'])
 df = df.dropna(subset=['city'])

# %% [markdown]
# ## Check a specific column

# %%
df['ppg']
# Out:
# 0         14.13
# 1          2.12
# 2          2.12
# 3         14.13
# 4         15.54
# 5          10.6
# 6          10.6
# 7          5.65
# 8          22.6
# 9         16.95
# 10         15.9
# 11        18.37
# 12         5.65
# 13         4.24
# 14          ten
# 15         6.36
# 16         2.47
# 17         4.24
# 18         7.07
# 19         7.77
# 20        15.54
# 21        14.12
# 22         4.24
# 23         2.47
# 24         15.9
# 25        12.37
# 26        14.12
# 27        14.84
# 28         3.53
# 29         8.47
#           ...
# 147053    10.25
# 147054     4.24
# 147055       20
# 147056     10.6
# 147057     6.36
# 147058     8.47
# 147059     7.07
# 147060     10.6
# 147061        3
# 147062     10.6
# 147063     5.65
# 147064     5.65
# 147065     10.6
# 147066     8.83
# 147067     6.36
# 147068      5.3
# 147069     5.65
# 147070        3
# 147071       20
# 147072     7.07
# 147073    16.95
# 147074     7.07
# 147075       20
# 147076        8
# ...

# %% [markdown]
# ## now check

# %%
df['ppg']>10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-44bb3a100a5b> in <module>()
# ----> 1 df['ppg']>10
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     877
#     878             with np.errstate(all='ignore'):
# --> 879                 res = na_op(values, other)
#     880             if is_scalar(res):
#     881                 raise TypeError('Could not compare {typ} type with Series'
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     781
#     782         if is_object_dtype(x.dtype):
# --> 783             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     784         else:
#     785
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#     761         result = lib.vec_compare(x, y, op)
#     762     else:
# --> 763         result = lib.scalar_compare(x, y, op)
# ...

# %% [markdown]
# ## TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df['ppg'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Try a fix

# %%
df['ppg'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-0d0dc035b33b> in <module>()
# ----> 1 df['ppg'].astype('float')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %% [markdown]
# ## Try again

# %%
import numpy as np

def check_float(value):
    try:
        float(value)
        return np.NaN
    except ValueError:
        return value

# %%
check_float('42'), check_float(1970.0)
# Out:
# (nan, nan)

# %%
df['ppg'].apply(check_float)
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        ten
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
#          ...
# 147053    NaN
# 147054    NaN
# 147055    NaN
# 147056    NaN
# 147057    NaN
# 147058    NaN
# 147059    NaN
# 147060    NaN
# 147061    NaN
# 147062    NaN
# 147063    NaN
# 147064    NaN
# 147065    NaN
# 147066    NaN
# 147067    NaN
# 147068    NaN
# 147069    NaN
# 147070    NaN
# 147071    NaN
# 147072    NaN
# 147073    NaN
# 147074    NaN
# 147075    NaN
# 147076    NaN
# 147077    NaN
# 147078    NaN
# 147079    NaN
# 147080    NaN
# 147081    NaN
# 147082    NaN
# ...

# %%
# df2 = df['ppg'].apply(check_float).dropna()

# %%
df[
    df['ppg'].astype(float) < 10
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-fada588b9daa> in <module>()
#       1 df[
# ----> 2     df['ppg'].astype(float) < 10
#       3 ]
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %%
df['ppg'].apply(check_float).dropna().value_counts().index[0]
# Out:
# 'ten'

# %% [markdown]
# ## Find the location

# %%
df.index[df['ppg'] == 'ten'].tolist()
# Out:
# [14]

# %% [markdown]
# ## Now use the index to find the row

# %%
df.loc[14]
# Out:
# city          Clearwater
# state                 FL
# price                 75
# amount             7.075
# quality             high
# date            9/2/2010
# ppg                  ten
# state.name       Florida
# lat              27.9328
# lon             -82.7248
# Name: 14, dtype: object

# %%
test = pd.Series([42, 3.1415, 'banana'])
test.apply(check_float)
# Out:
# 0       NaN
# 1       NaN
# 2    banana
# dtype: object

# %%
df.to_csv("newgooddata.csv")
